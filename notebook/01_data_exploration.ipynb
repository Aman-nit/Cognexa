# %%
print("Hello, Insurance Project!")
# Out:
# Hello, Insurance Project!

# %%
import pandas as pd

# %%
df = pd.read_excel("../data/Worksheet in Case Study question 2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_excel("../data/Worksheet in Case Study question 2.xlsx")
#
# File ~\OneDrive\Desktop\COGNEXA\venv\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
# ...

# %%
df = pd.read_excel(
    "../data/Worksheet in Case Study question 2.xlsx",
    engine="openpyxl"
)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_excel(
#       2     "../data/Worksheet in Case Study question 2.xlsx",
#       3     engine="openpyxl"
#       4 )
#
# File ~\OneDrive\Desktop\COGNEXA\venv\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
df = pd.read_excel(
    "../data/Worksheet in Case Study question 2.xlsx",
    engine="openpyxl"
)

# %%
df.shape
# Out:
# (1000, 39)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='str')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
df["fraud_reported"].value_counts()
# Out:
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64

# %%
(df == "?").sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# ...

# %%
missing_question = (df == "?").sum()
missing_question[missing_question > 0]
# Out:
# collision_type             178
# property_damage            360
# police_report_available    343
# dtype: int64

# %%
for col in ["collision_type", "property_damage", "police_report_available"]:
    print("\n", col)
    print(df[col].value_counts(dropna=False))
# Out:
#  collision_type
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: count, dtype: int64
#
#  property_damage
# property_damage
# ?      360
# NO     338
# YES    302
# Name: count, dtype: int64
#
#  police_report_available
# police_report_available
# ?      343
# NO     343
# YES    314
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# months_as_customer              0
# age                             0
# policy_number                   0
# policy_bind_date                0
# policy_state                    0
# policy_csl                      0
# policy_deductable               0
# policy_annual_premium           0
# umbrella_limit                  0
# insured_zip                     0
# insured_sex                     0
# insured_education_level         0
# insured_occupation              0
# insured_hobbies                 0
# insured_relationship            0
# capital-gains                   0
# capital-loss                    0
# incident_date                   0
# incident_type                   0
# collision_type                  0
# incident_severity               0
# authorities_contacted          91
# incident_state                  0
# incident_city                   0
# incident_location               0
# incident_hour_of_the_day        0
# number_of_vehicles_involved     0
# ...

# %%
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# authorities_contacted    91
# dtype: int64

# %%
df = df.replace("?", pd.NA)

# %%
df.isnull().sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted           91
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# ...

# %%
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# property_damage            360
# police_report_available    343
# collision_type             178
# authorities_contacted       91
# dtype: int64

# %%
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# property_damage            360
# police_report_available    343
# collision_type             178
# authorities_contacted       91
# dtype: int64

# %%
categorical_missing_cols = [
    "property_damage",
    "police_report_available",
    "collision_type",
    "authorities_contacted"
]

for col in categorical_missing_cols:
    df[col] = df[col].fillna("Unknown")

# %%
df[categorical_missing_cols].isnull().sum()
# Out:
# property_damage            0
# police_report_available    0
# collision_type             0
# authorities_contacted      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_number                           int64
# policy_bind_date               datetime64[us]
# policy_state                              str
# policy_csl                                str
# policy_deductable                       int64
# policy_annual_premium                 float64
# umbrella_limit                          int64
# insured_zip                             int64
# insured_sex                               str
# insured_education_level                   str
# insured_occupation                        str
# insured_hobbies                           str
# insured_relationship                      str
# capital-gains                           int64
# capital-loss                            int64
# incident_date                  datetime64[us]
# incident_type                             str
# collision_type                            str
# ...

# %%
df.describe().T
# Out:
#                               count                 mean                  min  \
# months_as_customer           1000.0              203.954                  0.0
# age                          1000.0               38.948                 19.0
# policy_number                1000.0           546238.648             100804.0
# policy_bind_date               1000  2002-02-08 04:40:48  1990-01-08 00:00:00
# policy_deductable            1000.0               1136.0                500.0
# policy_annual_premium        1000.0           1256.40615               433.33
# umbrella_limit               1000.0            1101000.0           -1000000.0
# insured_zip                  1000.0           501214.488             430104.0
# capital-gains                1000.0              25126.1                  0.0
# capital-loss                 1000.0             -26793.7            -111100.0
# incident_date                  1000  2015-01-30 08:02:24  2015-01-01 00:00:00
# ...

# %%
df.describe().T
# Out:
#                               count                 mean                  min  \
# months_as_customer           1000.0              203.954                  0.0
# age                          1000.0               38.948                 19.0
# policy_number                1000.0           546238.648             100804.0
# policy_bind_date               1000  2002-02-08 04:40:48  1990-01-08 00:00:00
# policy_deductable            1000.0               1136.0                500.0
# policy_annual_premium        1000.0           1256.40615               433.33
# umbrella_limit               1000.0            1101000.0           -1000000.0
# insured_zip                  1000.0           501214.488             430104.0
# capital-gains                1000.0              25126.1                  0.0
# capital-loss                 1000.0             -26793.7            -111100.0
# incident_date                  1000  2015-01-30 08:02:24  2015-01-01 00:00:00
# ...

# %%
df[df["umbrella_limit"] < 0]["umbrella_limit"].value_counts()
# Out:
# umbrella_limit
# -1000000    1
# Name: count, dtype: int64

# %%
df[df["umbrella_limit"] < 0].T
# Out:
#                                                   290
# months_as_customer                                284
# age                                                42
# policy_number                                  526039
# policy_bind_date                  1995-05-04 00:00:00
# policy_state                                       OH
# policy_csl                                    100/300
# policy_deductable                                 500
# policy_annual_premium                         1338.54
# umbrella_limit                               -1000000
# insured_zip                                    438178
# insured_sex                                      MALE
# insured_education_level                     Associate
# insured_occupation                  machine-op-inspct
# insured_hobbies                              kayaking
# insured_relationship                             wife
# capital-gains                                       0
# ...

# %%
df.loc[df["umbrella_limit"] >= 0, "umbrella_limit"].median()
# Out:
# np.float64(0.0)

# %%
df.loc[df["umbrella_limit"] < 0, "umbrella_limit"] = 0

# %%
df["umbrella_limit"].min()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["fraud_reported"].value_counts()
# Out:
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64

# %%
categorical_cols = df.select_dtypes(include=["object", "str"]).columns

for col in categorical_cols:
    print("\n---", col, "---")
    print(df[col].value_counts().head(15))
# Out:
# --- policy_state ---
# policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
#
# --- policy_csl ---
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: count, dtype: int64
#
# --- insured_sex ---
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
#
# --- insured_education_level ---
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
#
# --- insured_occupation ---
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
# ...

# %%
categorical_cols = df.select_dtypes(include=["object", "str"]).columns

for col in categorical_cols:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# policy_state: 3 unique values
# policy_csl: 3 unique values
# insured_sex: 2 unique values
# insured_education_level: 7 unique values
# insured_occupation: 14 unique values
# insured_hobbies: 20 unique values
# insured_relationship: 6 unique values
# incident_type: 4 unique values
# collision_type: 4 unique values
# incident_severity: 4 unique values
# authorities_contacted: 5 unique values
# incident_state: 7 unique values
# incident_city: 7 unique values
# incident_location: 1000 unique values
# property_damage: 3 unique values
# police_report_available: 3 unique values
# auto_make: 14 unique values
# auto_model: 39 unique values
# fraud_reported: 2 unique values

# %%
df = df.drop(columns=["incident_location"])

# %%
df.shape
# Out:
# (1000, 38)

# %%
print("policy_number:", df["policy_number"].nunique())
print("insured_zip:", df["insured_zip"].nunique())
# Out:
# policy_number: 1000
# insured_zip: 995

# %%
df = df.drop(columns=["policy_number", "insured_zip"])

# %%
df.shape
# Out:
# (1000, 36)

# %%
df = df.drop(columns=["policy_number", "insured_zip"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df = df.drop(columns=["policy_number", "insured_zip"])
#
# File ~\OneDrive\Desktop\COGNEXA\venv\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~\OneDrive\Desktop\COGNEXA\venv\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
# ...

# %%
df.shape
# Out:
# (1000, 36)

# %%
df.columns.tolist()
# Out:
# ['months_as_customer',
#  'age',
#  'policy_bind_date',
#  'policy_state',
#  'policy_csl',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'capital-gains',
#  'capital-loss',
#  'incident_date',
#  'incident_type',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'incident_state',
#  'incident_city',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'property_damage',
#  'bodily_injuries',
#  'witnesses',
#  'police_report_available',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_make',
#  'auto_model',
#  'auto_year',
#  'fraud_reported']

# %%
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %%
X = df.drop(columns=["fraud_reported"])

# %%
y = df["fraud_reported"]

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (1000, 35)
# y shape: (1000,)

# %%
y = y.map({"N": 0, "Y": 1})

# %%
y.value_counts()
# Out:
# fraud_reported
# 0    753
# 1    247
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (800, 35)
# X_test : (200, 35)
# y_train: (800,)
# y_test : (200,)

# %%
numeric_cols = X_train.select_dtypes(include=["int64", "float64"]).columns
categorical_cols = X_train.select_dtypes(include=["object", "str"]).columns

print("Numerical columns:", len(numeric_cols))
print("Categorical columns:", len(categorical_cols))
# Out:
# Numerical columns: 16
# Categorical columns: 17

# %%
print("\nNumerical:")
print(list(numeric_cols))

print("\nCategorical:")
print(list(categorical_cols))
# Out:
# Numerical:
# ['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']
#
# Categorical:
# ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model']

# %%
print(X_train[["policy_bind_date", "incident_date"]].head())
# Out:
#     policy_bind_date incident_date
# 887       2009-07-29    2015-02-19
# 317       1991-12-06    2015-01-18
# 796       1990-02-15    2015-01-12
# 425       2003-05-24    2015-02-12
# 991       2006-07-12    2015-02-06

# %%
for data in [X_train, X_test]:
    data["policy_bind_year"] = data["policy_bind_date"].dt.year
    data["policy_bind_month"] = data["policy_bind_date"].dt.month
    
    data["incident_year"] = data["incident_date"].dt.year
    data["incident_month"] = data["incident_date"].dt.month
    data["incident_day"] = data["incident_date"].dt.day
    
    data["policy_duration_days"] = (
        data["incident_date"] - data["policy_bind_date"]
    ).dt.days

# %%
X_train[
    [
        "policy_bind_year",
        "policy_bind_month",
        "incident_year",
        "incident_month",
        "incident_day",
        "policy_duration_days"
    ]
].head()
# Out:
#      policy_bind_year  policy_bind_month  incident_year  incident_month  \
# 887              2009                  7           2015               2
# 317              1991                 12           2015               1
# 796              1990                  2           2015               1
# 425              2003                  5           2015               2
# 991              2006                  7           2015               2
#
#      incident_day  policy_duration_days
# 887            19                  2031
# 317            18                  8444
# 796            12                  9097
# 425            12                  4282
# 991             6                  3131

# %%
X_train = X_train.drop(columns=["policy_bind_date", "incident_date"])
X_test = X_test.drop(columns=["policy_bind_date", "incident_date"])

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
# Out:
# X_train: (800, 39)
# X_test : (200, 39)

# %%
numeric_cols = X_train.select_dtypes(include=["int64", "float64"]).columns
categorical_cols = X_train.select_dtypes(include=["object", "str"]).columns

print("Numerical:", len(numeric_cols))
print("Categorical:", len(categorical_cols))
# Out:
# Numerical: 17
# Categorical: 17

# %%
print("Numerical columns:")
print(list(numeric_cols))

print("\nCategorical columns:")
print(list(categorical_cols))
# Out:
# Numerical columns:
# ['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year', 'policy_duration_days']
#
# Categorical columns:
# ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 preprocessor = ColumnTransformer(
#       2     transformers=[
#       3         ("num", StandardScaler(), numeric_cols),
#       4         ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
#
# NameError: name 'ColumnTransformer' is not defined

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
    ]
)

# %%
X_train_processed = preprocessor.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\OneDrive\Desktop\COGNEXA\venv\Lib\site-packages\sklearn\utils\_encode.py:177, in _unique_python(values, return_inverse, return_counts)
#     175 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 177 uniques = sorted(uniques_set)
#     178 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 X_train_processed = preprocessor.fit_transform(X_train)
#
# File ~\OneDrive\Desktop\COGNEXA\venv\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# ...

# %%
for col in categorical_cols:
    types = X_train[col].dropna().map(type).value_counts()
    if len(types) > 1:
        print(col)
        print(types)
# Out:
# auto_model
# auto_model
# <class 'str'>    759
# <class 'int'>     41
# Name: count, dtype: int64

# %%
X_train["auto_model"] = X_train["auto_model"].astype(str)
X_test["auto_model"] = X_test["auto_model"].astype(str)

# %%
print(X_train["auto_model"].map(type).value_counts())
# Out:
# auto_model
# <class 'str'>    800
# Name: count, dtype: int64

# %%
X_train_processed = preprocessor.fit_transform(X_train)

# %%
X_test_processed = preprocessor.transform(X_test)

# %%
print("Processed X_train:", X_train_processed.shape)
print("Processed X_test :", X_test_processed.shape)
# Out:
# Processed X_train: (800, 162)
# Processed X_test : (200, 162)
